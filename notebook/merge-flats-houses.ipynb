# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df1 = pd.read_csv('../data/flats_cleaned.csv')

# %%
df2 = pd.read_csv('../data/houses_cleaned.csv')

# %%
df = pd.concat([df1, df2], ignore_index = True)

# %%
df = df.sample(df.shape[0], ignore_index =True)

# %%
df
# Out:
#                                           property_name property_type  \
# 0                      3 BHK Flat in Sector 63A Gurgaon          flat
# 1                       4 BHK Flat in Sector 90 Gurgaon          flat
# 2     9 Bedroom House for sale in Palam Vihar Extension         house
# 3                       3 BHK Flat in Sector 53 Gurgaon          flat
# 4       1 Bedroom House for sale in Sushant Lok Phase 1         house
# 5                  3 Bedroom House for sale in Rosewood         house
# 6                       3 BHK Flat in Sector 79 Gurgaon          flat
# 7                       4 BHK Flat in Sector 86 Gurgaon          flat
# 8                       4 BHK Flat in Sector 86 Gurgaon          flat
# 9                      2 BHK Flat in Sector 112 Gurgaon          flat
# 10                     3 BHK Flat in Sector 82A Gurgaon          flat
# 11                      2 BHK Flat in Sector 85 Gurgaon          flat
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3955 entries, 0 to 3954
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3955 non-null   object
#  1   property_type    3955 non-null   object
#  2   society          3387 non-null   object
#  3   price            3954 non-null   float64
#  4   price_per_sqft   3954 non-null   float64
#  5   area             3954 non-null   float64
#  6   areaWithType     3955 non-null   object
#  7   bedRoom          3955 non-null   int64
#  8   bathroom         3955 non-null   int64
#  9   balcony          3955 non-null   object
#  10  additionalRoom   3955 non-null   object
#  11  address          3944 non-null   object
#  12  floorNum         3933 non-null   float64
#  13  facing           2783 non-null   object
#  14  agePossession    3954 non-null   object
#  15  nearbyLocations  3749 non-null   object
# ...

# %%
df.to_csv('gurgoan_properties.csv')

# %%
df.shape

# %%
df.sample(5)

# %%
df.insert(loc = 4, column = 'sector', value = df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon', '').str.strip())

# %%
df.head()

# %%
df['sector'] = df['sector'].str.lower()

# %%
df.head()
# Out:
#                      property_name property_type                   society  \
# 0  2 BHK Flat in Sector 79 Gurgaon          flat                    godrej
# 1  3 BHK Flat in Sector 70 Gurgaon          flat   shree vardhman victoria
# 2  4 BHK Flat in Sector 53 Gurgaon          flat            tulip monsella
# 3  3 BHK Flat in Sector 92 Gurgaon          flat            raheja sampada
# 4  2 BHK Flat in Sector 71 Gurgaon          flat  signature andour heights
#
#    price     sector  price_per_sqft    area  \
# 0   1.30  sector 79          8269.0  1572.0
# 1   1.63  sector 70          8358.0  1950.0
# 2   7.40  sector 53         33198.0  2229.0
# 3   0.65  sector 92          4744.0  1370.0
# 4   0.60  sector 71         10000.0   600.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0             Super Built up area 1572(146.04 sq.m.)        2         2
# 1  Super Built up area 1950(181.16 sq.m.)Carpet a...        3         5
# ...

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna                                                        163
# sector 102                                                   113
# sector 85                                                    110
# sector 92                                                    104
# sector 69                                                     94
# sector 65                                                     90
# sector 90                                                     90
# sector 81                                                     90
# sector 109                                                    88
# sector 79                                                     80
# sector 83                                                     69
# sector 37d                                                    68
# sector 86                                                     68
# sector 104                                                    66
# ...

# %%
a = df['sector'].value_counts()[df['sector'].value_counts() >= 2]
df = df[df['sector'].isin(a.index)]

# %%
df[df['sector'] == 'nirvana country']
# Out:
#                                     property_name property_type  \
# 55    5 Bedroom House for sale in Nirvana Country         house
# 63                  3 BHK Flat in Nirvana Country          flat
# 239                 2 BHK Flat in Nirvana Country          flat
# 274                 3 BHK Flat in Nirvana Country          flat
# 447   3 Bedroom House for sale in Nirvana Country         house
# 486                 3 BHK Flat in Nirvana Country          flat
# 586   6 Bedroom House for sale in Nirvana Country         house
# 793                 3 BHK Flat in Nirvana Country          flat
# 810                 3 BHK Flat in Nirvana Country          flat
# 829   5 Bedroom House for sale in Nirvana Country         house
# 915   5 Bedroom House for sale in Nirvana Country         house
# 1011                3 BHK Flat in Nirvana Country          flat
# 1065  5 Bedroom House for sale in Nirvana Country         house
# 1086                3 BHK Flat in Nirvana Country          flat
# ...

# %%
df['sector'] = df['sector'].str.replace('nirvana country', 'sector 50')
df['sector'] = df['sector'].str.replace('dlf phase 1', 'sector 26')
df['sector'] = df['sector'].str.replace('palam vihar', 'sector 23')
df['sector'] = df['sector'].str.replace('dlf phase 2', 'sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1', 'sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar', 'sector 3a')
df['sector'] = df['sector'].str.replace('dlf phase 4', 'sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3', 'sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 3', 'sector 57')
df['sector'] = df['sector'].str.replace('rajendra park', 'sector 105')
df['sector'] = df['sector'].str.replace('dlf phase 5', 'sector 43')
df['sector'] = df['sector'].str.replace('gwal pahari', 'sector 2')
df['sector'] = df['sector'].str.replace('laxman vihar phase 2', 'sector 4')
df['sector'] = df['sector'].str.replace('uppals southend', 'sector 49')
df['sector'] = df['sector'].str.replace('sohna road', 'sector 48')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension', 'sector 3')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2', 'sector 5')
df['sector'] = df['sector'].str.replace('south city 1', 'sector 41')
df['sector'] = df['sector'].str.replace('c block sushant lok phase 1', 'sector 43')
df['sector'] = df['sector'].str.replace('palam vihar extension', 'sector 22')
df['sector'] = df['sector'].str.replace('malibu town', 'sector 47')
df['sector'] = df['sector'].str.replace('new colony', 'sector 7')
df['sector'] = df['sector'].str.replace('rajiv nagar', 'sector 13')
df['sector'] = df['sector'].str.replace('jyoti park', 'sector 7')
df['sector'] = df['sector'].str.replace('jacobpura', 'sector 12a')
df['sector'] = df['sector'].str.replace('ashok vihar', 'sector 5')
df['sector'] = df['sector'].str.replace('greenwood city', 'sector 40')
df['sector'] = df['sector'].str.replace('ansal plaza', 'sector 23')
df['sector'] = df['sector'].str.replace('new palam vihar', 'sector 110')
df['sector'] = df['sector'].str.replace('subhash nagar', 'sector 8')
df['sector'] = df['sector'].str.replace('chakkarpur', 'sector 28')
df['sector'] = df['sector'].str.replace('sushant lok phase 2', 'sector 56')
df['sector'] = df['sector'].str.replace('arjun nagar', 'sector 8')
df['sector'] = df['sector'].str.replace('Saraswati Vihar, Gurgaon', 'sector 28')
df['sector'] = df['sector'].str.replace('dayanand colony', 'sector 6')
df['sector'] = df['sector'].str.replace('adarsh nagar', 'sector 12')
df['sector'] = df['sector'].str.replace('vishnu garden', 'sector 105')
df['sector'] = df['sector'].str.replace('ravi nagar', 'sector 9')
df['sector'] = df['sector'].str.replace('baldev nagar', 'sector 7')
df['sector'] = df['sector'].str.replace('surya vihar', 'sector 4')
df['sector'] = df['sector'].str.replace('suncity', 'sector 76')
df['sector'] = df['sector'].str.replace('madanpuri', 'sector 7')
df['sector'] = df['sector'].str.replace('shivpuri', 'sector 7')
df['sector'] = df['sector'].str.replace('krishna colony', 'sector 7')
df['sector'] = df['sector'].str.replace('valley view estate', 'sector 2')
df['sector'] = df['sector'].str.replace('bhim nagar', 'sector 6')
df['sector'] = df['sector'].str.replace('devilal colony', 'sector 9')
df['sector'] = df['sector'].str.replace('shivaji nagar', 'sector 11')
df['sector'] = df['sector'].str.replace('dharam colony', 'sector 12')
df['sector'] = df['sector'].str.replace('garhi harsaru', 'sector 88')
df['sector'] = df['sector'].str.replace('patel nagar', 'sector 15')
df['sector'] = df['sector'].str.replace('a block sushant lok phase 1', 'sector 27')
df['sector'] = df['sector'].str.replace('mg road', 'sector 25')
df['sector'] = df['sector'].str.replace('b block sushant lok phase 1', 'sector 30m')
df['sector'] = df['sector'].str.replace('prem nagar', 'sector 11')
df['sector'] = df['sector'].str.replace('maruti kunj', 'sector 62')
df['sector'] = df['sector'].str.replace('laxmi garden', 'sector 11')
df['sector'] = df['sector'].str.replace('gandhi nagar', 'sector 11')
df['sector'] = df['sector'].str.replace('ambience island', 'sector 24')
df['sector'] = df['sector'].str.replace('shakti nagar', 'sector 54')
df['sector'] = df['sector'].str.replace('sohna  road', 'sector 49')
df['sector'] = df['sector'].str.replace('daulatabad', 'sector 103')
df['sector'] = df['sector'].str.replace('lajpat nagar', 'sector 12')
df['sector'] = df['sector'].str.replace('hira nagar', 'sector 11')
df['sector'] = df['sector'].str.replace('samaspur', 'sector 51')
df['sector'] = df['sector'].str.replace('iffco chowk', 'sector 29')
df['sector'] = df['sector'].str.replace('new palam vihar phase 2', 'sector 110')
df['sector'] = df['sector'].str.replace('rajiv chowk', 'sector 33')
df['sector'] = df['sector'].str.replace('manohar nagar', 'sector 12')
df['sector'] = df['sector'].str.replace('sheetla colony', 'sector 5')
df['sector'] = df['sector'].str.replace('block a surya vihar', 'sector 4')
df['sector'] = df['sector'].str.replace('sispal vihar', 'sector 49')
df['sector'] = df['sector'].str.replace(', delhi ncr', 'sector 63')
df['sector'] = df['sector'].str.replace('new basti', 'sector 8')
df['sector'] = df['sector'].str.replace('pratap nagar', 'sector 8')
df['sector'] = df['sector'].str.replace('west rajiv nagar', 'sector 13')
df['sector'] = df['sector'].str.replace('acharya puri', 'sector 12')
df['sector'] = df['sector'].str.replace('surat nagar phase 2', 'sector 104')
df['sector'] = df['sector'].str.replace('faridabad road', 'sector 2')
df['sector'] = df['sector'].str.replace('sushant lok', 'sector 3')
df['sector'] = df['sector'].str.replace('mayfield garden', 'sector 51')
df['sector'] = df['sector'].str.replace('shankar vihar', 'sector 103')
df['sector'] = df['sector'].str.replace('bhawani enclave', 'sector 61')
df['sector'] = df['sector'].str.replace('rosewood', 'sector 49')
df['sector'] = df['sector'].str.replace('new palam vihar phase 1', 'sector 110')
df['sector'] = df['sector'].str.replace('shanti nagar', 'sector 11')
df['sector'] = df['sector'].str.replace('mohan vihar', 'sector 11')
df['sector'] = df['sector'].str.replace('surat nagar', 'sector 104')
df['sector'] = df['sector'].str.replace('ats marigold', 'sector 89a')
df['sector'] = df['sector'].str.replace('vir nagar', 'sector 8')
df['sector'] = df['sector'].str.replace('shankar vihar', 'sector 103')
df['sector'] = df['sector'].str.replace('shankar vihar', 'sector 103')
df['sector'] = df['sector'].str.replace('shankar vihar', 'sector 103')
df['sector'] = df['sector'].str.replace('shankar vihar', 'sector 103')
df['sector'] = df['sector'].str.replace('shankar vihar', 'sector 103')
df['sector'] = df['sector'].str.replace('shankar vihar', 'sector 103')
df['sector'] = df['sector'].str.replace('shankar vihar', 'sector 103')
df['sector'] = df['sector'].str.replace('shankar vihar', 'sector 103')
df['sector'] = df['sector'].str.replace('shankar vihar', 'sector 103')
df['sector'] = df['sector'].str.replace('shankar vihar', 'sector 103')
df['sector'] = df['sector'].str.replace('shankar vihar', 'sector 103')
# Out:
# /tmp/ipykernel_337531/2327422208.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('nirvana country', 'sector 50')
# /tmp/ipykernel_337531/2327422208.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('dlf phase 1', 'sector 26')
# /tmp/ipykernel_337531/2327422208.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df[df['sector'] == 'new']
# Out:
#                   property_name property_type                       society  \
# 600   2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
# 2226  4 BHK Flat in New Gurgaon          flat                        dlf 76
# 2387  4 BHK Flat in New Gurgaon          flat                    sare homes
# 3271  2 BHK Flat in New Gurgaon          flat                   green court
#
#       price sector  price_per_sqft    area  \
# 600    0.67    new          5583.0  1200.0
# 2226   4.00    new         11428.0  3500.0
# 2387   0.85    new          4786.0  1776.0
# 3271   0.38    new          5507.0   690.0
#
#                                 areaWithType  bedRoom  bathroom balcony  \
# 600   Super Built up area 1200(111.48 sq.m.)        2         2       2
# 2226        Carpet area: 3500 (325.16 sq.m.)        4         4       2
# 2387     Super Built up area 1776(165 sq.m.)        4         4       3
# 3271           Carpet area: 690 (64.1 sq.m.)        2         2       1
#
# ...

# %%
df.loc[1087,'sector'] = 'sector 37'
df.loc[2235,'sector'] = 'sector 92'
df.loc[2766,'sector'] = 'sector 90'
df.loc[2839,'sector'] = 'sector 76'

# %%
df.sample(3)
# Out:
#                         property_name property_type             society  \
# 1566  2 BHK Flat in Sector 77 Gurgaon          flat  umang winter hills
# 2034    3 BHK Flat in Nirvana Country          flat     the close north
# 196   4 BHK Flat in Sector 22 Gurgaon          flat  ambience creacions
#
#       price     sector  price_per_sqft    area  \
# 1566   0.75  sector 77          5588.0  1342.0
# 2034   2.70  sector 50         10364.0  2605.0
# 196    6.16  sector 22         20533.0  3000.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1566  Super Built up area 1342(124.68 sq.m.)Built Up...        2         2
# 2034  Super Built up area 2605(242.01 sq.m.)Built Up...        3         3
# 196                    Carpet area: 3000 (278.71 sq.m.)        4         5
#
#      balcony           additionalRoom  \
# 1566       2            not available
# 2034      3+             servant room
# 196       3+  pooja room,servant room
#
# ...

# %%
# features to drop -> property_name, address, description, rating
df.drop(columns=['property_name', 'address'],inplace=True)
# Out:
# /tmp/ipykernel_337531/970199603.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['property_name', 'address'],inplace=True)

# %%
df.duplicated().sum()
# Out:
# 13

# %%
# df.to_csv('gurgaon_properties_cleaned_v1.csv',index=False)
